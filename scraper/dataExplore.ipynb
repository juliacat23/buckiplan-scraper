# %%
import pandas as pd

# %%
courses = pd.read_csv("data/courses.csv")
PreReqs = courses['description'].str.split(pat = 'Prereq', n = 1, expand = True)
PreReqs.columns = ["description", "prereqs"]
PreReqs['prereqs'] = PreReqs['prereqs'].str.replace(r':', '')
PreReqs
# Out:
#                                             description  \
# 0     Workshops and course discussion designed to te...
# 1     This course will expose students to the key el...
# 2      Group study of special topics in various fields.
# 3     Assist students with mastering the fundamental...
# 4     This course is designed to help students with ...
# ...                                                 ...
# 8538  Examines concepts in feminist political theory...
# 8539  An introduction to and analysis of major texts...
# 8540  Examination of particular contemporary issues ...
# 8541  Yiddish 1101 is an introduction to the Yiddish...
# 8542  Reading and analysis of texts, films and music...
#
#                                                 prereqs
# 0         Young Scholars Program scholarship recipient.
# 1                                                  None
# 2      Permission of instructor. Repeatable to a max...
# 3                 Enrollment in Young Scholars Program.
# ...
